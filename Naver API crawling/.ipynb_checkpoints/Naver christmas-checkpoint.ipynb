# %%
import os
import sys
import urllib.request
import json
client_id = "8MRyI57fRtUYegAgKsoo"
client_secret = "yL6IUMzKbN"
word = urllib.parse.quote('크리스마스 데이트')
option = "&display=100"
url = "https://openapi.naver.com/v1/search/blog.json?query="
url_search = url + word + option

request = urllib.request.Request(url_search)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read().decode('utf-8')
    json_data = json.loads(response_body)
    print(json_data['items'])
#    with open('place_search_result.json', 'w') as f:
#        json.dump(json_data['items'], f, indent='\t')


else:
    print("Error Code:" + rescode)
    
#blog_link = []
#for i range(1:101):
#    blog_link.append(response_body)
# Out:
# [{'title': '울산 맛집 베스트 - <b>크리스마스 데이트</b>로 딱이구먼!', 'link': 'http://blog.naver.com/dbdkssk1004?Redirect=Log&amp;logNo=221412968500', 'description': '그러나 이런 멋진 곳에서 크리스마스 이브와 연말파티를 즐겨야 하지 않겠어요? 다행히도 12/24(월), 12... 회식장소, <b>크리스마스 데이트</b> 등.. 특별한 장소를 물색 중인 사람들 얼른 예약하시길 :) 근데 노쇼는... ', 'bloggername': '보리의 일상', 'bloggerlink': 'http://blog.naver.com/dbdkssk1004', 'postdate': '20181205'}, {'title': '범계역 맛집 - <b>크리스마스 데이트</b>로 딱이군!', 'link': 'http://blog.naver.com/dnalfl87?Redirect=Log&amp;logNo=221409430670', 'description': '그래서 워낙 레드 계통?이라 연말이나 <b>크리스마스</b>에 더 잘 어울리는 분위기라서 무조건 클스마스 <b>데이트</b> 장소는 여기다라고 생각했어요! 역시 <b>크리스마스</b>하면 미쿡 아닌가요?? 범계역 맛집 샤이바나 음식은... ', 'bloggername': '소혀뉘일상!', 'bloggerlink': 'http://blog.naver.com/dnalfl87', 'postdate': '20181130'}, {'title': '부산 <b>크리스마스 데이트</b>코스 완벽한 계획짜기! ♥', 'link': 'http://blog.naver.com/powerej2?Redirect=Log&amp;logNo=221411627866', 'description': '아무래도 저희가 부산 <b>크리스마스 데이트</b>코스 중에 하나로 넣어두었던 커플 스파 덕분이 아닐까 생각... 게다가 차스파 자체가 많은 분들이 부산 <b>크리스마스 데이트</b>코스로 꼽는건 물론이고 그냥 여행을... ', 'bloggername': '본격, 노는 로그 !', 'bloggerlink': 'http://blog.naver.com/powerej2', 'postdate': '20181204'}, {'title': '한남동 레스토랑 온다빌레 <b>크리스마스데이트</b>하기 제격인 곳!', 'link': 'http://blog.naver.com/llillo2?Redirect=Log&amp;logNo=221408364292', 'description': '이제 <b>크리스마스데이트</b>를 알아보시려고 하는 분들이 많을 텐데 그런 분들이 가기 좋은 곳으로... 분위기에 홀딱 반했을 정도로 저라면 좋은 사람이 생긴다면 <b>크리스마스데이트</b> 이곳으로 오지 않을까 싶더라고요.... ', 'bloggername': '우기부기블로그', 'bloggerlink': 'http://blog.naver.com/llillo2', 'postdate': '20181128'}, {'title': '<b>크리스마스 데이트</b>엔 이태원... 파인다이닝&gt; 한남동 데이트코스', 'link': 'http://blog.naver.com/pjjpdj?Redirect=Log&amp;logNo=221414118464', 'description': '물론 또 연말, 크리스마스가 되면 이런 분위기 있는 식사가 그리워 질테
# %%
# 크리스마스 가볼만한곳
json_items = json_data['items']
link_list = []
for i in range(len(json_items)):
    link_list.append(json_items[i]['link'])
    
for i in range(100):
    link_list[i] = link_list[i].replace("?Redirect=Log&amp;logNo=","/")
    
link_list
# Out:
# ['http://blog.naver.com/wnsgk111222/221412919131',
#  'http://blog.naver.com/belpehgor/221406734472',
#  'http://blog.naver.com/weeeunjee/221414373489',
#  'http://blog.naver.com/lyu1388/221414599396',
#  'http://blog.naver.com/julietmeeso/221411762951',
#  'http://blog.naver.com/suny1004x/221406484521',
#  'http://blog.naver.com/mystyle0504/221400093586',
#  'http://blog.naver.com/bahna2/221414322984',
#  'http://blog.naver.com/donna_fugata/221405956875',
#  'http://blog.naver.com/nata4224/221392534671',
#  'http://blog.naver.com/reina1124/221401845745',
#  'http://blog.naver.com/yojung0505/221393018919',
#  'http://blog.naver.com/yebinnies2/221411606426',
#  'http://blog.naver.com/ydl1/221165083685',
#  'http://blog.naver.com/onhijini74/221411992806',
#  'http://blog.naver.com/eumjeongoh/221167779188',
#  'http://blog.naver.com/lfhupbbimq/221412889476',
#  'http://blog.naver.com/kiki303030/221396297530',
#  'http://blog.naver.com/shy01095/221414467503',
#  'http://blog.naver.com/ringnrt/221410392943',
#  'http://blog.naver.com/tbseowlq00/221413783724',
#  'http://blog.naver.com/dlaehdgkspro/221413154731',
#  'http://blog.naver.com/tgcare0_0/221413666602',
#  'http://blog.naver.com/knh_0313/221168940440',
#  'http://blog.naver.com/kwpjulie/220874704627',
#  'http://blog.naver.com/mmmma85/221413434757',
#  'http://blog.naver.com/dallala526/221405511529',
#  'http://blog.naver.com/love20021102/221405153078',
#  'http://blog.naver.com/tnwlsdl702/221173301119',
#  'http://blog.naver.com/clytiemom/221414761105',
#  'http://blog.naver.com/pyj_5004/221413756666',
#  'http://blog.naver.com/e_leisurvice/221413840029',
#  'http://blog.naver.com/yuppie0429/221405524100',
#  'http://blog.naver.com/barabak82/220891343992',
#  'http://blog.naver.com/eun941/221166222276',
#  'http://blog.naver.com/ymodee/221409095543',
#  'http://blog.naver.com/monnani100/220872747182',
#  'http://blog.naver.com/oilservice11/220890010120',
#  'http://blog.naver.com/srhrae/221166142562',
#  'http://blog.naver.com/1004rahee/221413200033',
#  'http://blog.naver.com/pearlchong/220892571647',
#  'http://blog.naver.com/aksenthrtkf14/221394961411',
#  'http://blog.naver.com/svc1133/221413755934',
#  'http://blog.naver.com/daegu_news/221407774812',
#  'http://blog.naver.com/lilyme7/221169281598',
#  'http://blog.naver.com/95kg/221412981641',
#  'http://blog.naver.com/jmusuri/221170815786',
#  'http://blog.naver.com/mir7991/221408827699',
#  'http://blog.naver.com/hyjhs/221169055546',
#  'http://blog.naver.com/mormonlife/221409870217',
#  'http://blog.naver.com/kyj128090/221163935611',
#  'http://blog.naver.com/junght01/221401551764',
#  'http://blog.naver.com/pc_happy700/220889636632',
#  'http://blog.naver.com/lglghoho/221413636135',
#  'http://blog.naver.com/ymj5709/221161599545',
#  'http://blog.naver.com/azusim/221169054606',
#  'http://blog.naver.com/bif1966/221413590942',
#  'http://blog.naver.com/ddulbo77/220877244409',
#  'http://blog.naver.com/nyj8701/221093139488',
#  'http://blog.naver.com/lisasong1828/220886820177',
#  'http://blog.naver.com/ssangssangma/220891230285',
#  'http://blog.naver.com/chakanwolf1/221168239500',
#  'http://blog.naver.com/pinkpyh1018/221413975934',
#  'http://blog.naver.com/pilagency/221414504600',
#  'http://blog.naver.com/sidna/221164378678',
#  'http://blog.naver.com/qortmd457/221162169504',
#  'http://toycamera.tistory.com/2503',
#  'http://blog.naver.com/smh85/221393556011',
#  'http://blog.naver.com/tcacyc/221167800234',
#  'http://blog.naver.com/ihopebbq/221183699633',
#  'http://blog.naver.com/kshjhj0222/221414051953',
#  'http://blog.naver.com/real3622/221167332427',
#  'http://blog.naver.com/ooah9396/221170613664',
#  'http://blog.naver.com/hl7060/221167946366',
#  'http://blog.naver.com/bombs77/221413357434',
#  'http://blog.naver.com/yeongmiej/221413288898',
#  'http://blog.naver.com/yangju619/221156630013',
#  'http://blog.naver.com/gccity_blog/221407252187',
#  'http://blog.naver.com/dmgj2006/221167549810',
#  'http://blog.naver.com/dankookjet/221169721480',
#  'http://blog.naver.com/purum1021/221413982680',
#  'http://blog.naver.com/lovebm77/221168484048',
#  'http://blog.naver.com/gywjd55/221170906484',
#  'http://blog.naver.com/dankookjet/221170285092',
#  'http://blog.naver.com/herbisland/220890111565',
#  'http://blog.naver.com/0081bm/221406779249',
#  'http://blog.naver.com/fds6051/220885485539',
#  'http://blog.naver.com/dnsmking/221412372193',
#  'http://blog.naver.com/noriter4u/220891514079',
#  'http://blog.naver.com/mira3483/221167537114',
#  'http://blog.naver.com/junght01/221145783015',
#  'http://blog.naver.com/sopoongjeju/221409012962',
#  'http://blog.naver.com/jhym9594/221169553374',
#  'http://blog.naver.com/daeguvisit/220576355906',
#  'http://blog.naver.com/turpu/220846529374',
#  'http://blog.naver.com/hope_city/220575535503',
#  'http://blog.naver.com/hkhj8083/220567970523',
#  'http://blog.naver.com/wodbs0129/220565451000',
#  'http://blog.naver.com/qookssam/220218190645',
#  'http://hwaseongcity.tistory.com/3106']

# %%
with open('place_url_list.txt', 'w') as f:
    for item in link_list:
        f.write("%s\n" % item)
    f.close()

# %%
# 크리스마스 데이트
json_items = json_data['items']
link_list = []
for i in range(len(json_items)):
    link_list.append(json_items[i]['link'])
    
for i in range(100):
    link_list[i] = link_list[i].replace("?Redirect=Log&amp;logNo=","/")
    
link_list
# Out:
# ['http://blog.naver.com/dbdkssk1004/221412968500',
#  'http://blog.naver.com/dnalfl87/221409430670',
#  'http://blog.naver.com/powerej2/221411627866',
#  'http://blog.naver.com/sporobic/221414235279',
#  'http://blog.naver.com/mint__s2/221410113665',
#  'http://blog.naver.com/y___eun/221408816246',
#  'http://blog.naver.com/junght01/221393583394',
#  'http://blog.naver.com/sihwarae/221412534189',
#  'http://blog.naver.com/khr8532/221405446756',
#  'http://blog.naver.com/banjinoriter/221414346927',
#  'http://blog.naver.com/choike99/221401025376',
#  'http://blog.naver.com/twodeers/221408613057',
#  'http://blog.naver.com/volare1011/221408055675',
#  'http://blog.naver.com/luvdayy/221406783426',
#  'http://blog.naver.com/estrella0109/221414323580',
#  'http://blog.naver.com/tisltisl5517/221412926227',
#  'http://blog.naver.com/cocoo0224/221413992960',
#  'http://blog.naver.com/syhcity/221413078986',
#  'http://blog.naver.com/uuubini/221411936374',
#  'http://blog.naver.com/learnway8/221411293153',
#  'http://blog.naver.com/cruiserlaw/221405082246',
#  'http://blog.naver.com/ardiente_/221414378365',
#  'http://blog.naver.com/ysryung/221411577934',
#  'http://blog.naver.com/kimhyunhi218/221395027284',
#  'http://blog.naver.com/ajdajddl29/221414727414',
#  'http://blog.naver.com/ringuniv_bg/221414708335',
#  'http://blog.naver.com/aroma_a/221408663455',
#  'http://blog.naver.com/hyobaru/221414177211',
#  'http://blog.naver.com/wlgp2711/221412015627',
#  'http://blog.naver.com/kayemoon1/221402168068',
#  'http://blog.naver.com/yeongcheonsi/221407226775',
#  'http://blog.naver.com/szvivasz/221407599581',
#  'http://blog.naver.com/susang66/221407400969',
#  'http://blog.naver.com/noljathenolja/221413774876',
#  'http://blog.naver.com/dbwndud218/221403680350',
#  'http://blog.naver.com/ecruise00/221412259535',
#  'http://blog.naver.com/elena4249/221413845044',
#  'http://blog.naver.com/hiri2475/221414275876',
#  'http://blog.naver.com/kk4165310/221413942261']

# %%
with open('date_url_list.txt', 'w') as f:
    for item in link_list:
        f.write("%s\n" % item)
    f.close()

# %%
import os
import sys
import urllib.request
import json
client_id = "8MRyI57fRtUYegAgKsoo"
client_secret = "yL6IUMzKbN"
word = urllib.parse.quote(input("키워드: "))
option = "&display=100"
url = "https://openapi.naver.com/v1/search/blog.json?query="
url_search = url + word + option

request = urllib.request.Request(url_search)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read().decode('utf-8')
    json_data = json.loads(response_body)
#    print(json_data['items'])

    json_items = json_data['items']
    print(len(json_items))
    for i in range(len(json_items)):
        print(json_items[i]['link'])

else:
    print("Error Code:" + rescode)

# %%
#데이터랩 트랜드 분석
import os
import sys
import urllib.request
client_id = "8MRyI57fRtUYegAgKsoo"
client_secret = "yL6IUMzKbN"
url = "https://openapi.naver.com/v1/datalab/search";
body = "{\"startDate\":\"2017-12-01\",\"endDate\":\"2017-12-25\",\"timeUnit\":\"month\",\"keywordGroups\":[{\"groupName\":\"크리스마스\",\"keywords\":[\"크리스마스\"]},{\"groupName\":\"크리스마스 데이트\",\"keywords\":[\"크리스마스 데이트\"]}, {\"groupName\":\"크리스마스 가볼만한곳\",\"keywords\":[\"크리스마스 가볼만한곳\"]}]}";

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read().decode('utf-8')
    print(response_body)
else:
    print("Error Code:" + rescode)
