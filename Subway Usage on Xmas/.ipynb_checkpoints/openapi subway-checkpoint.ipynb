# %% [markdown]
# 필요한 일자가 있을 경우 sample code에 YYYYMMDD 형식으로 날짜 입력!

# %%
#sample code
import urllib.request
import json
from collections import OrderedDict

api_key = "42467970507368303731506c745754"
date = input()
base_url = "http://openapi.seoul.go.kr:8088/{}/json/CardSubwayStatsNew/1/1000/{}".format(api_key, date)

print(base_url)

with urllib.request.urlopen(base_url) as response:
    data = response.read()
    usage = json.loads(data)
    parsed_data = usage['CardSubwayStatsNew']['row']
    
print(parsed_data)
# Out:
# 20141225
# http://openapi.seoul.go.kr:8088/42467970507368303731506c745754/json/CardSubwayStatsNew/1/1000/20141225
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-858199d11cc5> in <module>
#      13     data = response.read()
#      14     usage = json.loads(data)
# ---> 15     parsed_data = usage['CardSubwayStatsNew']['row']
#      16
#      17 print(parsed_data)
#
# KeyError: 'CardSubwayStatsNew'

# %%
#json 파일로 저장
with open("{}_usage.json".format(date), 'w') as f:
    json.dump(parsed_data, f, indent='\t')

# %% [markdown]
# 2017년 크리스마스 일자별 지하철 이용 정보

# %%
for i in range(20171223,20171227):
    url = "http://openapi.seoul.go.kr:8088/42467970507368303731506c745754/json/CardSubwayStatsNew/1/1000/{}".format(i)
    with urllib.request.urlopen(url) as response:
        data = response.read()
        usage = json.loads(data)
        parsed_data = usage['CardSubwayStatsNew']['row']
    
    with open('{}_usage.json'.format(i),'w') as f:
        json.dump(parsed_data, f, indent='\t')

# %% [markdown]
# 2016 크리스마스 일자별 지하철 이용 정보

# %%
for i in range(20161223,20161227):
    url = "http://openapi.seoul.go.kr:8088/42467970507368303731506c745754/json/CardSubwayStatsNew/1/1000/{}".format(i)
    with urllib.request.urlopen(url) as response:
        data = response.read()
        usage = json.loads(data)
        parsed_data = usage['CardSubwayStatsNew']['row']
    
    with open('{}_usage.json'.format(i),'w') as f:
        json.dump(parsed_data, f, indent='\t')

# %% [markdown]
# 2015 크리스마스 일자별 지하철 이용 정보

# %%
jfor i in range(20151223,20151227):
    url = "http://openapi.seoul.go.kr:8088/42467970507368303731506c745754/json/CardSubwayStatsNew/1/1000/{}".format(i)
    with urllib.request.urlopen(url) as response:
        data = response.read()
        usage = json.loads(data)
        parsed_data = usage['CardSubwayStatsNew']['row']
    
    with open('{}_usage.json'.format(i),'w', encoding = 'utf-8') as f:
        json.dump(parsed_data, f, indent='\t')

# %%
import urllib.request
import json
from collections import OrderedDict
from pandas import DataFrame

with open('20171125_usage.json', 'r', encoding = 'utf-8') as f:
    data = json.load(f)

data = DataFrame(data)
data.sort()
# Out:
#      ALIGHT_PASGR_NUM LINE_NUM  RIDE_PASGR_NUM    SUB_STA_NM    USE_DT  \
# 0             55286.0      1호선         56449.0           서울역  20171125
# 1             18741.0      1호선         19486.0            시청  20171125
# 2             35825.0      1호선         36016.0            종각  20171125
# 3             33198.0      1호선         33918.0          종로3가  20171125
# 4             27685.0      1호선         28835.0          종로5가  20171125
# 5             17982.0      1호선         16132.0           동대문  20171125
# 6             13231.0      1호선         13462.0           신설동  20171125
# 7             19092.0      1호선         18997.0           제기동  20171125
# 8             28029.0      1호선         26400.0  청량리(서울시립대입구)  20171125
# 9             10530.0      1호선         10311.0           동묘앞  20171125
# 10            12635.0      2호선         15508.0            시청  20171125
# 11            41378.0      2호선         42350.0         을지로입구  20171125
# 12            12161.0      2호선         13208.0         을지로3가  20171125
# 13            10090.0      2호선         10711.0         을지로4가  20171125
# 14            21137.0      2호선         18962.0     동대문역사문화공원  20171125
# 15            14677.0      2호선         14079.0            신당  20171125
# 16            10500.0      2호선         11534.0          상왕십리  20171125
# 17            16649.0      2호선         19617.0     왕십리(성동구청)  20171125
# 18            11023.0      2호선         10812.0           한양대  20171125
# 19            11455.0      2호선         11421.0            뚝섬  20171125
# 20            18326.0      2호선         17127.0            성수  20171125
# 21            51691.0      2호선         45796.0          건대입구  20171125
# 22            18629.0      2호선         19279.0      구의(광진구청)  20171125
# 23            55866.0      2호선         56427.0    강변(동서울터미널)  20171125
# 24            13142.0      2호선         13664.0          잠실나루  20171125
# 25            87923.0      2호선         93524.0      잠실(송파구청)  20171125
# 26            25904.0      2호선         24091.0          잠실새내  20171125
# 27            10474.0      2호선          9558.0         종합운동장  20171125
# 28            53168.0      2호선         53506.0      삼성(무역센터)  20171125
# 29            30170.0      2호선         35878.0            선릉  20171125
# ..                ...      ...             ...           ...       ...
# 547            9920.0      일산선          8894.0           정발산  20171125
# 548            8526.0      일산선          8675.0            주엽  20171125
# 549           13126.0      일산선         15363.0            대화  20171125
# 550            1033.0      장항선          1098.0            봉명  20171125
# 551            2137.0      장항선          2529.0      쌍용(나사렛대)  20171125
# 552            3388.0      장항선          3657.0            아산  20171125
# 553            1214.0      장항선          1253.0            배방  20171125
# 554            6158.0      장항선          5976.0          온양온천  20171125
# 555            1681.0      장항선          1953.0      신창(순천향대)  20171125
# 556           35099.0      중앙선         36141.0            회기  20171125
# 557            5233.0      중앙선          5256.0            중랑  20171125
# 558            4962.0      중앙선          4988.0   상봉(시외버스터미널)  20171125
# 559            8041.0      중앙선          8116.0            망우  20171125
# 560            1854.0      중앙선          2075.0            양원  20171125
# 561           13745.0      중앙선         12955.0            구리  20171125
# 562            6784.0      중앙선          7739.0            도농  20171125
# 563             616.0      중앙선           791.0            양정  20171125
# 564            5572.0      중앙선          5642.0            덕소  20171125
# 565            1840.0      중앙선          2096.0            도심  20171125
# 566            1044.0      중앙선           981.0            팔당  20171125
# 567             735.0      중앙선           846.0           운길산  20171125
# 568            1780.0      중앙선          1619.0            양수  20171125
# 569             214.0      중앙선           223.0            신원  20171125
# 570             843.0      중앙선           850.0            국수  20171125
# 571             774.0      중앙선           750.0            아신  20171125
# 572             435.0      중앙선           410.0            오빈  20171125
# 573            3687.0      중앙선          3417.0            양평  20171125
# 574             499.0      중앙선           462.0            원덕  20171125
# 575            3835.0      중앙선          3531.0            용문  20171125
# 576              30.0      중앙선            31.0            지평  20171125
#
#       WORK_DT
# 0    20171128
# 1    20171128
# 2    20171128
# 3    20171128
# 4    20171128
# 5    20171128
# 6    20171128
# 7    20171128
# 8    20171128
# 9    20171128
# 10   20171128
# 11   20171128
# 12   20171128
# 13   20171128
# 14   20171128
# 15   20171128
# 16   20171128
# 17   20171128
# 18   20171128
# 19   20171128
# 20   20171128
# 21   20171128
# 22   20171128
# 23   20171128
# 24   20171128
# 25   20171128
# 26   20171128
# 27   20171128
# 28   20171128
# 29   20171128
# ..        ...
# 547  20171128
# 548  20171128
# 549  20171128
# 550  20171128
# 551  20171128
# 552  20171128
# 553  20171128
# 554  20171128
# 555  20171128
# 556  20171128
# 557  20171128
# 558  20171128
# 559  20171128
# 560  20171128
# 561  20171128
# 562  20171128
# 563  20171128
# 564  20171128
# 565  20171128
# 566  20171128
# 567  20171128
# 568  20171128
# 569  20171128
# 570  20171128
# 571  20171128
# 572  20171128
# 573  20171128
# 574  20171128
# 575  20171128
# 576  20171128
#
# [577 rows x 6 columns]

# %%
--

# %%
for i in range(578):
    print(data[i])
# Out:
# 577
