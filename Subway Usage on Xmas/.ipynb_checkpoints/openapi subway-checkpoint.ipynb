# %% [markdown]
# 필요한 일자가 있을 경우 sample code에 YYYYMMDD 형식으로 날짜 입력!

# %%
#sample code
import urllib.request
import json
from collections import OrderedDict

api_key = "42467970507368303731506c745754"
date = input()
base_url = "http://openapi.seoul.go.kr:8088/{}/json/CardSubwayStatsNew/1/1000/{}".format(api_key, date)

print(base_url)

with urllib.request.urlopen(base_url) as response:
    data = response.read()
    usage = json.loads(data)
    parsed_data = usage['CardSubwayStatsNew']['row']
    
print(parsed_data)
# Out:
# 20171125
# http://openapi.seoul.go.kr:8088/42467970507368303731506c745754/json/CardSubwayStatsNew/1/1000/20171125
# [{'USE_DT': '20171125', 'LINE_NUM': '1호선', 'SUB_STA_NM': '서울역', 'RIDE_PASGR_NUM': 56449.0, 'ALIGHT_PASGR_NUM': 55286.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '1호선', 'SUB_STA_NM': '시청', 'RIDE_PASGR_NUM': 19486.0, 'ALIGHT_PASGR_NUM': 18741.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '1호선', 'SUB_STA_NM': '종각', 'RIDE_PASGR_NUM': 36016.0, 'ALIGHT_PASGR_NUM': 35825.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '1호선', 'SUB_STA_NM': '종로3가', 'RIDE_PASGR_NUM': 33918.0, 'ALIGHT_PASGR_NUM': 33198.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '1호선', 'SUB_STA_NM': '종로5가', 'RIDE_PASGR_NUM': 28835.0, 'ALIGHT_PASGR_NUM': 27685.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '1호선', 'SUB_STA_NM': '동대문', 'RIDE_PASGR_NUM': 16132.0, 'ALIGHT_PASGR_NUM': 17982.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '1호선', 'SUB_STA_NM': '신설동', 'RIDE_PASGR_NUM': 13462.0, 'ALIGHT_PASGR_NUM': 13231.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '1호선', 'SUB_STA_NM': '제기동', 'RIDE_PASGR_NUM': 18997.0, 'ALIGHT_PASGR_NUM': 19092.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '1호선', 'SUB_STA_NM': '청량리(서울시립대입구)', 'RIDE_PASGR_NUM': 26400.0, 'ALIGHT_PASGR_NUM': 28029.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '1호선', 'SUB_STA_NM': '동묘앞', 'RIDE_PASGR_NUM': 10311.0, 'ALIGHT_PASGR_NUM': 10530.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '2호선', 'SUB_STA_NM': '시청', 'RIDE_PASGR_NUM': 15508.0, 'ALIGHT_PASGR_NUM': 12635.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '2호선', 'SUB_STA_NM': '을지로입구', 'RIDE_PASGR_NUM': 42350.0, 'ALIGHT_PASGR_NUM': 41378.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '2호선', 'SUB_STA_NM': '을지로3가', 'RIDE_PASGR_NUM': 13208.0, 'ALIGHT_PASGR_NUM': 12161.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '2호선', 'SUB_STA_NM': '을지로4가', 'RIDE_PASGR_NUM': 10711.0, 'ALIGHT_PASGR_NUM': 10090.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '2호선', 'SUB_STA_NM': '동대문역사문화공원', 'RIDE_PASGR_NUM': 18962.0, 'ALIGHT_PASGR_NUM': 21137.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '2호선', 'SUB_STA_NM': '신당', 'RIDE_PASGR_NUM': 14079.0, 'ALIGHT_PASGR_NUM': 14677.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '2호선', 'SUB_STA_NM': '상왕십리', 'RIDE_PASGR_NUM': 11534.0, 'ALIGHT_PASGR_NUM': 10500.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '2호선', 'SUB_STA_NM': '왕십리(성동구청)', 'RIDE_PASGR_NUM': 19617.0, 'ALIGHT_PASGR_NUM': 16649.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '2호선', 'SUB_STA_NM': '한양대', 'RIDE_PASGR_NUM': 10812.0, 'ALIGHT_PASGR_NUM': 11023.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '2호선', 'SUB_STA_NM': '뚝섬', 'RIDE_PASGR_NUM': 11421.0, 'ALIGHT_PASGR_NUM': 11455.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '2호선', 'SUB_STA_NM': '성수', 'RIDE_PASGR_NUM': 17127.0, 'ALIGHT_PASGR_NUM': 18326.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '2호선', 'SUB_STA_NM': '건대입구', 'RIDE_PASGR_NUM': 45796.0, 'ALIGHT_PASGR_NUM': 51691.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '2호선', 'SUB_STA_NM': '구의(광진구청)', 'RIDE_PASGR_NUM': 19279.0, 'ALIGHT_PASGR_NUM': 18629.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '2호선', 'SUB_STA_NM': '강변(동서울터미널)', 'RIDE_PASGR_NUM': 56427.0, 'ALIGHT_PASGR_NUM': 55866.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '2호선', 'SUB_STA_NM': '잠실나루', 'RIDE_PASGR_NUM': 13664.0, 'ALIGHT_PASGR_NUM': 13142.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '2호선', 'SUB_STA_NM': '잠실(송파구청)', 'RIDE_PASGR_NUM': 93524.0, 'ALIGHT_PASGR_NUM': 87923.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '2호선', 'SUB_STA_NM': '잠실새내', 'RIDE_PASGR_NUM': 24091.0, 'ALIGHT_PASGR_NUM': 25904.0, 'WORK_DT': '20171128'}, {'USE_DT': '20171125', 'LINE_NUM': '2호선', 'SUB_STA_NM': '종합운동장', 'RIDE_PASGR_NUM': 9558.0, 'AL ...

# %%
#json 파일로 저장
with open("{}_usage.json".format(date), 'w') as f:
    json.dump(parsed_data, f, indent='\t')

# %% [markdown]
# 2017년 크리스마스 일자별 지하철 이용 정보

# %%
for i in range(20171223,20171227):
    url = "http://openapi.seoul.go.kr:8088/42467970507368303731506c745754/json/CardSubwayStatsNew/1/1000/{}".format(i)
    with urllib.request.urlopen(url) as response:
        data = response.read()
        usage = json.loads(data)
        parsed_data = usage['CardSubwayStatsNew']['row']
    
    with open('{}_usage.json'.format(i),'w') as f:
        json.dump(parsed_data, f, indent='\t')

# %% [markdown]
# 2016 크리스마스 일자별 지하철 이용 정보

# %%
for i in range(20161223,20161227):
    url = "http://openapi.seoul.go.kr:8088/42467970507368303731506c745754/json/CardSubwayStatsNew/1/1000/{}".format(i)
    with urllib.request.urlopen(url) as response:
        data = response.read()
        usage = json.loads(data)
        parsed_data = usage['CardSubwayStatsNew']['row']
    
    with open('{}_usage.json'.format(i),'w') as f:
        json.dump(parsed_data, f, indent='\t')

# %% [markdown]
# 2015 크리스마스 일자별 지하철 이용 정보

# %%
for i in range(20151223,20151227):
    url = "http://openapi.seoul.go.kr:8088/42467970507368303731506c745754/json/CardSubwayStatsNew/1/1000/{}".format(i)
    with urllib.request.urlopen(url) as response:
        data = response.read()
        usage = json.loads(data)
        parsed_data = usage['CardSubwayStatsNew']['row']
    
    with open('{}_usage.json'.format(i),'w') as f:
        json.dump(parsed_data, f, indent='\t')
