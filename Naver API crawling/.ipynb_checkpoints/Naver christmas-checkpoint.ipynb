# %%
import os
import sys
import urllib.request
import json
client_id = "8MRyI57fRtUYegAgKsoo"
client_secret = "yL6IUMzKbN"
word = urllib.parse.quote('크리스마스 데이트')
option = "&display=100"
url = "https://openapi.naver.com/v1/search/blog.json?query="
url_search = url + word + option

request = urllib.request.Request(url_search)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read().decode('utf-8')
    json_data = json.loads(response_body)
#    print(json_data['items'])
    with open('search_result.json', 'a') as f:
        json.dump(json_data['items'], f, indent='\t')


else:
    print("Error Code:" + rescode)
    
#blog_link = []
#for i range(1:101):
#    blog_link.append(response_body)

# %%
print(response_body)
# Out:
# {
# "lastBuildDate": "Fri, 07 Dec 2018 19:06:59 +0900",
# "total": 208593,
# "start": 1,
# "display": 100,
# "items": [
# {
# "title": "울산 맛집 베스트 - <b>크리스마스 데이트</b>로 딱이구먼!",
# "link": "http://blog.naver.com/dbdkssk1004?Redirect=Log&amp;logNo=221412968500",
# "description": "그러나 이런 멋진 곳에서 크리스마스 이브와 연말파티를 즐겨야 하지 않겠어요? 다행히도 12/24(월), 12... 회식장소, <b>크리스마스 데이트</b> 등.. 특별한 장소를 물색 중인 사람들 얼른 예약하시길 :) 근데 노쇼는... ",
# "bloggername": "보리의 일상",
# "bloggerlink": "http://blog.naver.com/dbdkssk1004",
# "postdate": "20181205"
#
# },
# {
# "title": "범계역 맛집 - <b>크리스마스 데이트</b>로 딱이군!",
# "link": "http://blog.naver.com/dnalfl87?Redirect=Log&amp;logNo=221409430670",
# "description": "그래서 워낙 레드 계통?이라 연말이나 <b>크리스마스</b>에 더 잘 어울리는 분위기라서 무조건 클스마스 <b>데이트</b> 장소는 여기다라고 생각했어요! 역시 <b>크리스마스</b>하면 미쿡 아닌가요?? 범계역 맛집 샤이바나 음식은... ",
# "bloggername": "소혀뉘일상!",
# "bloggerlink": "http://blog.naver.com/dnalfl87",
# "postdate": "20181130"
#
# },
# {
# "title": "부산 <b>크리스마스 데이트</b>코스 완벽한 계획짜기! ♥",
# ...

# %%
json_items = json_data['items']
link
for i in range(len(json_items)):
    print(json_items[i]['link'])
# Out:
# 100
# http://blog.naver.com/dbdkssk1004?Redirect=Log&amp;logNo=221412968500
# http://blog.naver.com/dnalfl87?Redirect=Log&amp;logNo=221409430670
# http://blog.naver.com/powerej2?Redirect=Log&amp;logNo=221411627866
# http://blog.naver.com/llillo2?Redirect=Log&amp;logNo=221408364292
# http://blog.naver.com/pjjpdj?Redirect=Log&amp;logNo=221414118464
# http://blog.naver.com/happy_love02?Redirect=Log&amp;logNo=221412465607
# http://blog.naver.com/leesoohyun87?Redirect=Log&amp;logNo=221413533334
# http://blog.naver.com/akane2045?Redirect=Log&amp;logNo=221413597184
# http://blog.naver.com/sky52640?Redirect=Log&amp;logNo=221406897562
# http://blog.naver.com/gpalc14?Redirect=Log&amp;logNo=221413538838
# http://blog.naver.com/roynmin?Redirect=Log&amp;logNo=221404762448
# http://blog.naver.com/gkdud5505?Redirect=Log&amp;logNo=221406334081
# http://blog.naver.com/mborim?Redirect=Log&amp;logNo=221407623024
# http://blog.naver.com/iamheozzang?Redirect=Log&amp;logNo=221413720870
# ...
