# %%
import os
import sys
import urllib.request
import json
client_id = "8MRyI57fRtUYegAgKsoo"
client_secret = "yL6IUMzKbN"
word = urllib.parse.quote('서울 크리스마스 데이트')
option = "&display=100"
url = "https://openapi.naver.com/v1/search/blog.json?query="
url_search = url + word + option

request = urllib.request.Request(url_search)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read().decode('utf-8')
    json_data = json.loads(response_body)
    print(json_data['items'])
#    with open('place_search_result.json', 'w') as f:
#        json.dump(json_data['items'], f, indent='\t')


else:
    print("Error Code:" + rescode)
    
#blog_link = []
#for i range(1:101):
#    blog_link.append(response_body)
# Out:
# [{'title': '<b>서울 크리스마스 데이트</b> 장소 추천 ! 서울드래곤시티 호텔... ', 'link': 'http://blog.naver.com/jej7634?Redirect=Log&amp;logNo=221413946204', 'description': '보낼 <b>크리스마스</b> <b>데이트</b> 장소로도 정말 좋을 것 같아요. 그리고 <b>서울</b>드래곤시티에는 예쁘고 뷰도 좋은 객실까지 마련되어 있잖아요 ?! 흐하 여기서 하루 머물면 정말.. 너무 행복할 것 같지 않나요 ?! 행복이... ', 'bloggername': '연우로그 뷰티톡', 'bloggerlink': 'http://blog.naver.com/jej7634', 'postdate': '20181206'}, {'title': '<b>서울 크리스마스 데이트</b> 아주 특별한 이색경험', 'link': 'http://blog.naver.com/ijw2qumtl72lz9?Redirect=Log&amp;logNo=221406809518', 'description': '저는 9시 반쯤에 10시 예약하고 싶어요~ 덕분에 서울 밤 데이트 장소로 유명하다고 <b>서울 크리스마스 데이트</b> 기념일에 와서 추억을 만들어도 관리 카드를 작성하는데 있어서 순조롭게 저희가 원하는대로 문제 없이... ', 'bloggername': 'ijw2qumtl72lz9님의블로그', 'bloggerlink': 'http://blog.naver.com/ijw2qumtl72lz9', 'postdate': '20181126'}, {'title': '<b>서울 크리스마스 데이트</b> 안성맞춤 호캉스 반값으로!', 'link': 'http://blog.naver.com/lfcqircz5?Redirect=Log&amp;logNo=221402427583', 'description': '그래도 제가 갔다옴으로써 잇님들은 <b>서울 크리스마스 데이트</b>로 올 수 있겠구나 싶어서 포스팅을 하게 되었는데요, 주변에서
# ...

# %% [markdown]
# 크리스마스 가볼만한곳 검색결과 url list 저장

# %%
# 크리스마스 가볼만한곳
json_items = json_data['items']
link_list = []
for i in range(len(json_items)):
    link_list.append(json_items[i]['link'])
    
for i in range(100):
    link_list[i] = link_list[i].replace("?Redirect=Log&amp;logNo=","/")
    
link_list
# Out:
# ['http://blog.naver.com/wnsgk111222/221412919131',
#  'http://blog.naver.com/belpehgor/221406734472',
#  'http://blog.naver.com/weeeunjee/221414373489',
#  'http://blog.naver.com/lyu1388/221414599396',
#  'http://blog.naver.com/julietmeeso/221411762951',
#  'http://blog.naver.com/suny1004x/221406484521',
#  'http://blog.naver.com/mystyle0504/221400093586',
#  'http://blog.naver.com/bahna2/221414322984',
#  'http://blog.naver.com/donna_fugata/221405956875',
#  'http://blog.naver.com/nata4224/221392534671',
#  'http://blog.naver.com/reina1124/221401845745',
#  'http://blog.naver.com/yojung0505/221393018919',
#  'http://blog.naver.com/yebinnies2/221411606426',
#  'http://blog.naver.com/ydl1/221165083685',
#  'http://blog.naver.com/onhijini74/221411992806',
#  'http://blog.naver.com/eumjeongoh/221167779188',
#  'http://blog.naver.com/lfhupbbimq/221412889476',
#  'http://blog.naver.com/kiki303030/221396297530',
#  'http://blog.naver.com/shy01095/221414467503',
# ...

# %%
with open('place_url_list.txt', 'w') as f:
    for item in link_list:
        f.write("%s\n" % item)
    f.close()

# %% [markdown]
# 크리스마스 데이트 검색결과 url 저장

# %%
# 크리스마스 데이트
json_items = json_data['items']
link_list = []
for i in range(len(json_items)):
    link_list.append(json_items[i]['link'])
    
for i in range(100):
    link_list[i] = link_list[i].replace("?Redirect=Log&amp;logNo=","/")
    
link_list
# Out:
# ['http://blog.naver.com/jej7634/221413946204',
#  'http://blog.naver.com/ijw2qumtl72lz9/221406809518',
#  'http://blog.naver.com/lfcqircz5/221402427583',
#  'http://blog.naver.com/whwndud7/221414579710',
#  'http://blog.naver.com/uaq70znywvrnk/221409571954',
#  'http://blog.naver.com/uufccb1ji6/221408913312',
#  'http://blog.naver.com/iamheozzang/221413720870',
#  'http://blog.naver.com/41bkj8vv5fp1/221406868047',
#  'http://blog.naver.com/yjkim1373/221414619750',
#  'http://blog.naver.com/syyypfmnbdroeq/221408305404',
#  'http://blog.naver.com/royal1234567/221412410697',
#  'http://blog.naver.com/8wxnwugy7fj9/221413446860',
#  'http://blog.naver.com/gfknz86yph9/221413856970',
#  'http://blog.naver.com/x0fl2cirt7l/221412295042',
#  'http://blog.naver.com/leesoohyun87/221413533334',
#  'http://blog.naver.com/z9eeehvcrk/221413444298',
#  'http://blog.naver.com/txx3r2qvccga/221413879657',
#  'http://blog.naver.com/epak6bndv/221413084164',
# ...

# %%
with open('date_url_list.txt', 'w') as f:
    for item in link_list:
        f.write("%s\n" % item)
    f.close()

# %% [markdown]
# 키워드 직접 넣어 검색 코드 - 링크만 return

# %%
import os
import sys
import urllib.request
import json
client_id = "8MRyI57fRtUYegAgKsoo"
client_secret = "yL6IUMzKbN"
word = urllib.parse.quote('서울 크리스마스 데이트')
option = "&display=100"
url = "https://openapi.naver.com/v1/search/blog.json?query="
url_search = url + word + option

request = urllib.request.Request(url_search)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read().decode('utf-8')
    json_data = json.loads(response_body)
#    print(json_data['items'])

    json_items = json_data['items']
#    print(json_items)
    for i in range(len(json_items)):
        print(json_items[i]['title'],json_items[i]['description'],json_items[i]['link'].replace("?Redirect=Log&amp;logNo=","/"))

else:
    print("Error Code:" + rescode)
# Out:
# <b>서울 크리스마스 데이트</b> 장소 추천 ! 서울드래곤시티 호텔...  보낼 <b>크리스마스</b> <b>데이트</b> 장소로도 정말 좋을 것 같아요. 그리고 <b>서울</b>드래곤시티에는 예쁘고 뷰도 좋은 객실까지 마련되어 있잖아요 ?! 흐하 여기서 하루 머물면 정말.. 너무 행복할 것 같지 않나요 ?! 행복이...  http://blog.naver.com/jej7634/221413946204
# <b>서울 크리스마스 데이트</b> 아주 특별한 이색경험 저는 9시 반쯤에 10시 예약하고 싶어요~ 덕분에 서울 밤 데이트 장소로 유명하다고 <b>서울 크리스마스 데이트</b> 기념일에 와서 추억을 만들어도 관리 카드를 작성하는데 있어서 순조롭게 저희가 원하는대로 문제 없이...  http://blog.naver.com/ijw2qumtl72lz9/221406809518
# <b>서울 크리스마스 데이트</b> 안성맞춤 호캉스 반값으로! 그래도 제가 갔다옴으로써 잇님들은 <b>서울 크리스마스 데이트</b>로 올 수 있겠구나 싶어서 포스팅을 하게 되었는데요, 주변에서 데이트를 즐기고 저녁에는 호텔에서 호캉스하며 보내보시면 여느 크리스마스 날과...  http://blog.naver.com/lfcqircz5/221402427583
# 미리가본 <b>서울 크리스마스 데이트</b> 품격있는 켄싱턴 브로드웨이 좋은 <b>서울 크리스마스 데이트</b> 하고 왔습니다 흥청망청 부어라 마셔라 하는 망년회 말고 우아하고... 그래서 서울 데이트 코스 켄싱턴 브로드웨이 추천하는 것이지요 오픈시간대에 방문했음에도 벌써 사람들이...  http://blog.naver.com/whwndud7/221414579710
# ...

# %% [markdown]
# 네이버 데이터랩 트랜드 분석 코드

# %%
#데이터랩 트랜드 분석
import os
import sys
import urllib.request
client_id = "8MRyI57fRtUYegAgKsoo"
client_secret = "yL6IUMzKbN"
url = "https://openapi.naver.com/v1/datalab/search";
body = "{\"startDate\":\"2017-12-01\",\"endDate\":\"2017-12-25\",\"timeUnit\":\"month\",\"keywordGroups\":[{\"groupName\":\"크리스마스\",\"keywords\":[\"크리스마스\"]},{\"groupName\":\"크리스마스 데이트\",\"keywords\":[\"크리스마스 데이트\"]}, {\"groupName\":\"크리스마스 가볼만한곳\",\"keywords\":[\"크리스마스 가볼만한곳\"]}]}";

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read().decode('utf-8')
    print(response_body)
else:
    print("Error Code:" + rescode)
